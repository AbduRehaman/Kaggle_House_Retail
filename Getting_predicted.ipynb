# %%
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import cv2
# %matplotlib inline
import math
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %%
def get_edges_prewitt_vertical(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges_prewitt_vertical = prewitt_v(image)
    return edges_prewitt_vertical

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
new_list_train = []
for i in os.listdir('folder_filled/train_images/train'):
    image = cv2.imread('folder_filled/train_images/train/'+i)
    image = cv2.resize(image, (50, 50))
    new_list_train.append(get_edges_prewitt_vertical(image))

new_list_test = []
for i in os.listdir('folder_filled/test_images/test'):
    image = cv2.imread('folder_filled/test_images/test/'+i)
    image = cv2.resize(image, (50, 50))
    new_list_test.append(get_edges_prewitt_vertical(image))

# %%
df_train_pca = pd.DataFrame(new_list_train[0].reshape(1, -1))
df_test_pca = pd.DataFrame(new_list_test[0].reshape(1, -1))

# %%
for i in range(1, len(new_list_train)):
    df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
for i in range(1, len(new_list_test)):
    df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# Out:
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train_pca = df_train_pca.append(pd.DataFrame(new_list_train[i].reshape(1,-1)))
# ...
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))
# /var/folders/hx/zshnl3dj6w33t23ztn0vvq6h0000gn/T/ipykernel_38483/314992117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test_pca = df_test_pca.append(pd.DataFrame(new_list_test[i].reshape(1,-1)))

# %%
scaler_train = StandardScaler()
scaler_train.fit(df_train_pca)
scaled_data_train = scaler_train.transform(df_train_pca)
pca = PCA(n_components=2)
pca.fit(scaled_data_train)
train_pca = pca.transform(scaled_data_train)

# %%
scaler_test = StandardScaler()
scaler_test.fit(df_test_pca)
scaled_data_test = scaler_test.transform(df_test_pca)
pca = PCA(n_components=2)
pca.fit(scaled_data_test)
test_pca = pca.transform(scaled_data_test)

# %%
df_train = pd.read_csv('folder_filled/train.csv')
df_train.drop(['toilets','image_id','address','city'], axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    index  rooms  retail_price    sqft
# 0   5832    2.0        299000  1295.0
# 1   5584    3.0        299000  1566.0
# 2   9408    5.0        499990  3068.0
# 3   4644    4.0        849900  2230.0
# 4   5739    3.0        333490  1898.0

# %%
df_test = pd.read_csv('folder_filled/test.csv')
df_test.drop(['toilets','image_id','address','city'], axis=1, inplace=True)
df_test.head()
# Out:
#    index  rooms  sqft
# 0   3076      3  1510
# 1   3218      4  2342
# 2   9213      2  2845
# 3  10018      4  2379
# 4  11355      4  1836

# %%
import re

# %%
id_test = [] 
for i in os.listdir('folder_filled/test_images/test'):
    id_test.append(i.split('.')[0])
id_test
# Out:
# ['9733',
#  '63',
#  '6400',
#  '823',
#  '5109',
#  '11759',
#  '6372',
#  '11995',
#  '10453',
#  '10335',
#  '9727',
#  '77',
#  '5135',
#  '7722',
#  '9069',
#  '11765',
#  '6428',
#  '11017',
#  '5121',
#  '5874',
#  '11956',
#  '10490',
#  '7911',
#  '2869',
#  '2699',
#  '6399',
#  '176',
#  '5684',
#  '2855',
#  '1384',
#  '9257',
#  '2464',
#  '10123',
#  '6602',
#  '9531',
#  '6616',
#  '9525',
#  '10137',
#  '11567',
#  '3020',
#  '4997',
#  '10679',
#  '5451',
#  '8175',
#  '5337',
#  '3746',
#  '10686',
#  '4968',
#  '6819',
#  '3961',
#  '3975',
#  '8820',
#  '6825',
#  '412',
#  '6831',
#  '4940',
#  '5519',
#  '1019',
#  '6762',
#  '8997',
#  '599',
#  '4175',
#  '2262',
#  '10725',
#  '4613',
#  '5525',
#  '1743',
#  '9479',
#  '6992',
#  '8767',
#  '7454',
#  '3626',
#  '1031',
#  '8015',
#  '7326',
#  '1757',
#  '5531',
#  '8798',
#  '10080',
#  '3801',
#  '1970',
#  '4808',
#  '214',
#  '4820',
#  '572',
#  '6945',
#  '3183',
#  '8559',
#  '957',
#  '10255',
#  '4363',
#  '10533',
#  '6212',
#  '9135',
#  '4377',
#  '6560',
#  '10269',
#  '1541',
#  '7130',
#  '5727',
#  '11605',
#  '5733',
#  '1555',
#  '8217',
#  '9684',
#  '758',
#  '980',
#  '9848',
#  '2935',
#  '1582',
#  '2921',
#  '4388',
#  '7859',
#  '9874',
#  '5929',
#  '765',
#  '9861',
#  '3394',
#  '5915',
#  '981',
#  '10297',
#  '5732',
#  '11162',
#  '3425',
#  '1226',
#  '7657',
#  '3431',
#  '2049',
#  '4438',
#  '8202',
#  '1568',
#  '9134',
#  '2707',
#  '10254',
#  '6575',
#  '8558',
#  '2075',
#  '10532',
#  '567',
#  '3182',
#  '2288',
#  '10917',
#  '3196',
#  '3828',
#  '5281',
#  '3800',
#  '4809',
#  '229',
#  '3814',
#  '8941',
#  '1030',
#  '2539',
#  '3627',
#  '4148',
#  '3141',
#  '5530',
#  '7327',
#  '8014',
#  '1742',
#  '7333',
#  '5524',
#  '8996',
#  '598',
#  '6763',
#  '8028',
#  '2263',
#  '6011',
#  '7469',
#  '1018',
#  '9444',
#  '11348',
#  '4160',
#  '375',
#  '7290',
#  '4799',
#  '5493',
#  '4955',
#  '361',
#  '8809',
#  '9295',
#  '10687',
#  '6818',
#  '8835',
#  '1144',
#  '5322',
#  '5444',
#  '7247',
#  '1636',
#  '11566',
#  '2459',
#  '5336',
#  '1150',
#  '4000',
#  '9524',
#  '9242',
#  '10650',
#  '10888',
#  '4766',
#  '2303',
#  '4772',
#  '6165',
#  '9901',
#  '3592',
#  '7086',
#  '6398',
#  '11957',
#  '5861',
#  '2868',
#  '639',
#  '9929',
#  '1420',
#  '8362',
#  '7051',
#  '4558',
#  '5646',
#  '5120',
#  '10308',
#  '11016',
#  '2897',
#  '7737',
#  '11764',
#  '9068',
#  '1434',
#  '2115',
#  '6373',
#  '9040',
#  '9726',
#  '2673',
#  '2667',
#  '10320',
#  '3579',
#  '62',
#  '6367',
#  '11028',
#  '6417',
#  '3209',
#  '4566',
#  '10444',
#  '8348',
#  '6403',
#  '9730',
#  '4214',
#  '2665',
#  '9718',
#  '8406',
#  '5122',
#  '5644',
#  '3235',
#  '7053',
#  '8374',
#  '1436',
#  '5650',
#  '11766',
#  '3221',
#  '3547',
#  '2659',
#  '9081',
#  '9095',
#  '11799',
#  '11941',
#  '3590',
#  '1387',
#  '175',
#  '7090',
#  '4599',
#  '11969',
#  '5687',
#  '5693',
#  '607',
#  '6173',
#  '9526',
#  '10646',
#  '3989',
#  '7537',
#  '1146',
#  '11564',
#  '9268',
#  '1807',
#  '10849',
#  '3962',
#  '1813',
#  '411',
#  '405',
#  '363',
#  '4957',
#  '10726',
#  '9452',
#  '8994',
#  '4176',
#  '10040',
#  '2507',
#  '5268',
#  '2513',
#  '6775',
#  '8980',
#  '9320',
#  '4604',
#  '8016',
#  '3143',
#  '11404',
#  '5254',
#  '6985',
#  '7443',
#  '1026',
#  '6991',
#  '10068',
#  '5240',
#  '3157',
#  '7331',
#  '8002',
#  '1998',
#  '1973',
#  '3802',
#  '559',
#  '9485',
#  '4837',
#  '565',
#  '6952',
#  '217',
#  '1783',
#  '10915',
#  '4823',
#  '2705',
#  '4374',
#  '9136',
#  '10524',
#  '4406',
#  '3369',
#  '5718',
#  '7669',
#  '9644',
#  '2711',
#  '11606',
#  '6239',
#  '1556',
#  '8214',
#  '5724',
#  '1224',
#  '9678',
#  '983',
#  '5917',
#  '10295',
#  '9687',
#  '997',
#  '1595',
#  '2088',
#  '7696',
#  '2936',
#  '3397',
#  '11808',
#  '2937',
#  '7697',
#  '2923',
#  '3383',
#  '5902',
#  '11834',
#  '996',
#  '9692',
#  '5916',
#  '5725',
#  '11613',
#  '7132',
#  '1543',
#  '8567',
#  '3432',
#  '11161',
#  '5057',
#  '7640',
#  '8573',
#  '7126',
#  '8215',
#  '3340',
#  '6210',
#  '10531',
#  '2710',
#  '955',
#  '4375',
#  '8229',
#  '9137',
#  '6204',
#  '570',
#  '1782',
#  '4836',
#  '10900',
#  '3181',
#  '6947',
#  '10096',
#  '1966',
#  '1972',
#  '3803',
#  '10082',
#  '10069',
#  '7456',
#  '1741',
#  '8003',
#  '11411',
#  '6984',
#  '1033',
#  '5255',
#  '8981',
#  '6774',
#  '2512',
#  '10055',
#  '4605',
#  '2274',
#  '7318',
#  '4611',
#  '11439',
#  '4177',
#  '6827',
#  '2499',
#  '3787',
#  '5484',
#  '8836',
#  '438',
#  '3977',
#  '1153',
#  '9269',
#  '4981',
#  '4759',
#  '8605',
#  '11217',
#  '3750',
#  '5321',
#  '4017',
#  '2466',
#  '5309',
#  '11559',
#  '1609',
#  '9255',
#  '6172',
#  '160',
#  '9902',
#  '11968',
#  '10492',
#  '3220',
#  '5889',
#  '5651',
#  '5137',
#  '2880',
#  '5123',
#  '3552',
#  '2894',
#  '7734',
#  '809',
#  '8407',
#  '9719',
#  '9057',
#  '10445',
#  '2664',
#  '4215',
#  '7708',
#  '9725',
#  '4201',
#  '10451',
#  '11997',
#  '9043',
#  '10469',
#  '11777',
#  '5899',
#  '3230',
#  '7056',
#  '7730',
#  '3556',
#  '5127',
#  '11005',
#  '5133',
#  '1355',
#  '9709',
#  '8371',
#  '9047',
#  '4563',
#  '10333',
#  '6406',
#  '7718',
#  '825',
#  '4211',
#  '4577',
#  '3218',
#  '4588',
#  '11978',
#  '164',
#  '7081',
#  '5866',
#  '11788',
#  '9090',
#  '11944',
#  '3754',
#  '7532',
#  '7254',
#  '5443',
#  '3026',
#  '5457',
#  '2338',
#  '7526',
#  '8615',
#  '5331',
#  '6610',
#  '5319',
#  '4007',
#  '4761',
#  '2310',
#  '1619',
#  '6176',
#  '399',
#  '2462',
#  '9537',
#  '6604',
#  '414',
#  '2489',
#  '7297',
#  '5494',
#  '4952',
#  '10694',
#  '10858',
#  '8832',
#  '5251',
#  '1037',
#  '7446',
#  '8013',
#  '2258',
#  '7452',
#  '8761',
#  '8749',
#  '10045',
#  '2502',
#  '2264',
#  '7308',
#  '9325',
#  '6016',
#  '10737',
#  '2270',
#  '4167',
#  '2516',
#  '4198',
#  '7491',
#  '6957',
#  '574',
#  '1962',
#  '5735',
#  '7122',
#  '979',
#  '7644',
#  '4359',
#  '8563',
#  '1547',
#  '6228',
#  '8205',
#  '3350',
#  '5721',
#  '10509',
#  '9133',
#  '4417',
#  '5709',
#  '4371',
#  '7678',
#  '6566',
#  '9655',
#  '789',
#  '10253',
#  '4403',
#  '10535',
#  '9127',
#  '8239',
#  '5090',
#  '776',
#  '7693',
#  '5912',
#  '986',
#  '10284',
#  '7877',
#  '5906',
#  '10291',
#  '11825',
#  '10285',
#  '7862',
#  '1585',
#  '11819',
#  '9873',
#  '6598',
#  '9640',
#  '950',
#  '9898',
#  '8238',
#  '6215',
#  '10534',
#  '2067',
#  '9132',
#  '1208',
#  '7679',
#  '10246',
#  '4358',
#  '5046',
#  '5720',
#  '8204',
#  '1546',
#  '8210',
#  '1552',
#  '11164',
#  '9668',
#  '1963',
#  '8947',
#  '3806',
#  '1977',
#  '4827',
#  '575',
#  '7490',
#  '4199',
#  '561',
#  '4600',
#  '6017',
#  '2517',
#  '4172',
#  '6765',
#  '9456',
#  '6003',
#  '9330',
#  '5522',
#  '5244',
#  '11372',
#  '8760',
#  '6981',
#  '7447',
#  '6759',
#  '1036',
#  '10078',
#  '5536',
#  '8012',
#  '1988',
#  '7321',
#  '10681',
#  '429',
#  '8199',
#  '5495',
#  '7282',
#  '3782',
#  '1181',
#  '373',
#  '10871',
#  '5481',
#  '4774',
#  '6605',
#  '9536',
#  '8628',
#  '10124',
#  '3769',
#  '10130',
#  '2311',
#  '10656',
#  '4990',
#  '11206',
#  '3741',
#  '1156',
#  '11212',
#  '5324',
#  '5442',
#  '11945',
#  '5867',
#  '11789',
#  '7080',
#  '165',
#  '5697',
#  '7094',
#  '2852',
#  '4210',
#  '6407',
#  '1368',
#  '9052',
#  '4576',
#  '10454',
#  '830',
#  '2885',
#  '3543',
#  '11762',
#  '7043',
#  '6349',
#  '2649',
#  '5126',
#  '2891',
#  '3557',
#  '11010',
#  '11006',
#  '1356',
#  '7727',
#  '8400',
#  '3555',
#  '3233',
#  '2105',
#  '11984',
#  '9050',
#  '9736',
#  '66',
#  '8428',
#  '826',
#  '10324',
#  '2663',
#  '5118',
#  '10330',
#  '6411',
#  '11748',
#  '601',
#  '3582',
#  '2850',
#  '7096',
#  '5681',
#  '9093',
#  '5871',
#  '5865',
#  '10495',
#  '8399',
#  '9508',
#  '3025',
#  '5454',
#  '7243',
#  '6149',
#  '7257',
#  '11576',
#  '5440',
#  '4038',
#  '3757',
#  '7531',
#  '4010',
#  '6613',
#  '9520',
#  '2475',
#  '4004',
#  '3958',
#  '403',
#  '1197',
#  '7280',
#  '365',
#  '10867',
#  '371',
#  '6834',
#  '3964',
#  '1815',
#  '10697',
#  '8825',
#  '8762',
#  '8004',
#  '11402',
#  '11364',
#  '3623',
#  '5252',
#  '6983',
#  '9440',
#  '6015',
#  '4616',
#  '3179',
#  '9332',
#  '1008',
#  '7479',
#  '2501',
#  '8979',
#  '1785',
#  '3186',
#  '1791',
#  '1949',
#  '6940',
#  '563',
#  '6798',
#  '3810',
#  '10091',
#  '4819',
#  '8206',
#  '7653',
#  '7647',
#  '10278',
#  '5050',
#  '3421',
#  '3347',
#  '7121',
#  '8212',
#  '2071',
#  '10250',
#  '4366',
#  '10244',
#  '9656',
#  '9130',
#  '6203',
#  '1587',
#  '775',
#  '4399',
#  '5087',
#  '761',
#  '9871',
#  '9681',
#  '749',
#  '9859',
#  '991',
#  '2918',
#  '11199',
#  '5911',
#  '5904',
#  '748',
#  '760',
#  '3385',
#  '5938',
#  '3391',
#  '5086',
#  '7691',
#  '9657',
#  '947',
#  '10245',
#  '4415',
#  '9131',
#  '1579',
#  '3408',
#  '10251',
#  '6570',
#  '8575',
#  '7646',
#  '2058',
#  '4429',
#  '3346',
#  '3352',
#  '8561',
#  '9496',
#  '8950',
#  '8788',
#  '10084',
#  '3811',
#  '6969',
#  '1960',
#  '4818',
#  '2299',
#  '3839',
#  '6941',
#  '1784',
#  '210',
#  '9333',
#  '5509',
#  '10047',
#  '9455',
#  '1009',
#  '9441',
#  '589',
#  '4165',
#  '4603',
#  '2272',
#  '9327',
#  '3144',
#  '6982',
#  '9469',
#  '2528',
#  '7450',
#  '1747',
#  '3150',
#  '10696',
#  '1800',
#  '6809',
#  '3971',
#  '10682',
#  '6821',
#  '402',
#  '4950',
#  '364',
#  '8159',
#  '9247',
#  '9535',
#  '6606',
#  '3018',
#  '10669',
#  '5441',
#  '7256',
#  '1141',
#  '11211',
#  '2448',
#  '5333',
#  '1155',
#  '8617',
#  '7242',
#  '5455',
#  '5864',
#  '9092',
#  '7901',
#  '1380',
#  '2689',
#  '7083',
#  '166',
#  '2845',
#  '3583',
#  '833',
#  '73',
#  '2676',
#  '10331',
#  '3568',
#  '4561',
#  '2110',
#  '9045',
#  '6362',
#  '9051',
#  '11985',
#  '2662',
#  '4213',
#  '8429',
#  '3554',
#  '7732',
#  '1425',
#  '8367',
#  '7054',
#  '5643',
#  '11761',
#  '3226',
#  '5657',
#  '1431',
#  '8373',
#  '4512',
#  '2605',
#  '6463',
#  '14',
#  '854',
#  '4260',
#  '11048',
#  '11706',
#  '6339',
#  '8472',
#  '4248',
#  '3527',
#  '9778',
#  '28',
#  '8466',
#  '1442',
#  '5817',
#  '7966',
#  '10395',
#  '7972',
#  '11935',
#  '3282',
#  '5195',
#  '667',
#  '11909',
#  '115',
#  '1481',
#  '9552',
#  '6661',
#  '10140',
#  '10626',
#  '9234',
#  '1668',
#  '7219',
#  '10632',
#  '2413',
#  '11262',
#  '7543',
#  '8670',
#  '1132',
#  '8116',
#  '11504',
#  '3057',
#  '11510',
#  '8102',
#  '1898',
#  '8664',
#  '6891',
#  '6649',
#  '10168',
#  '11276',
#  '10829',
#  '465',
#  '4089',
#  '5397',
#  '303',
#  '1697',
#  '7594',
#  '2573',
#  '4664',
#  '9340',
#  '5208',
#  '11316',
#  '10008',
#  '1046',
#  '7437',
#  '8062',
#  '1720',
#  '4880',
#  '3137',
#  '5552',
#  '4894',
#  '11464',
#  '9368',
#  '7423',
#  '11302',
#  '5234',
#  '10949',
#  '6932',
#  '3692',
#  '277',
#  '7392',
#  '6098',
#  '10961',
#  '2598',
#  '2017',
#  '5778',
#  '11896',
#  '2771',
#  '10236',
#  '4300',
#  '1278',
#  '10222',
#  ...]

# %%
test_pca = pd.DataFrame(test_pca, columns=['pca1', 'pca2'])
test_pca['index'] = id_test
test_pca.head()
# Out:
#        pca1      pca2 index
# 0 -7.145548 -2.091513  9733
# 1 -2.805897 -0.680594    63
# 2 -2.446419  2.956026  6400
# 3  0.816946 -4.360773   823
# 4  0.060708  1.542937  5109

# %%
id_train = [] 
for i in os.listdir('folder_filled/train_images/train'):
    id_train.append(i.split('.')[0])
id_train
# Out:
# ['4217',
#  '3578',
#  '10321',
#  '2666',
#  '11981',
#  '10447',
#  '2100',
#  '4571',
#  '7078',
#  '1409',
#  '9055',
#  '6366',
#  '189',
#  '9041',
#  '2114',
#  '4565',
#  '4203',
#  '2672',
#  '6414',
#  '8439',
#  '837',
#  '2882',
#  '3544',
#  '11003',
#  '1353',
#  '8411',
#  '7044',
#  '8377',
#  '1435',
#  '5653',
#  '3222',
#  '5647',
#  '2128',
#  '3236',
#  '11771',
#  '4559',
#  '7050',
#  '8363',
#  '1421',
#  '1347',
#  '7736',
#  '8405',
#  '2896',
#  '3550',
#  '10309',
#  '9928',
#  '638',
#  '7905',
#  '9096',
#  '8388',
#  '11942',
#  '10484',
#  '5860',
#  '9082',
#  '9914',
#  '7939',
#  '1390',
#  '604',
#  '2841',
#  '3587',
#  '5848',
#  '5690',
#  '162',
#  '7087',
#  '7093',
#  '3593',
#  '9900',
#  '88',
#  '610',
#  '6164',
#  '8149',
#  '4773',
#  '2302',
#  '10645',
#  '4015',
#  '7508',
#  '1179',
#  '2470',
#  '11229',
#  '4001',
#  '10889',
#  '4767',
#  '3008',
#  '2316',
#  '10651',
#  '5479',
#  '6170',
#  '9243',
#  '6158',
#  '1637',
#  '7246',
#  '8613',
#  '7520',
#  '1151',
#  '2458',
#  '11201',
#  '4029',
#  '5323',
#  '11215',
#  '3752',
#  '8607',
#  '7534',
#  '1145',
#  '9519',
#  '1623',
#  '8161',
#  '7252',
#  '11573',
#  '3034',
#  '4983',
#  '5445',
#  '11598',
#  '1810',
#  '9294',
#  '8834',
#  '1804',
#  '9280',
#  '348',
#  '10692',
#  '7285',
#  '360',
#  '4954',
#  '5492',
#  '10862',
#  '3785',
#  '406',
#  '1192',
#  '8808',
#  '1186',
#  '3791',
#  '3949',
#  '5486',
#  '4798',
#  '10876',
#  '1838',
#  '7291',
#  '374',
#  '6010',
#  '9323',
#  '2276',
#  '10731',
#  '3168',
#  '4607',
#  '4161',
#  '11349',
#  '2510',
#  '10057',
#  '6776',
#  '9445',
#  '8983',
#  '7468',
#  '9451',
#  '2504',
#  '10043',
#  '8029',
#  '6004',
#  '9337',
#  '11413',
#  '3154',
#  '8001',
#  '7332',
#  '1025',
#  '11375',
#  '3632',
#  '5243',
#  '4149',
#  '11361',
#  '2538',
#  '5257',
#  '6986',
#  '8773',
#  '7440',
#  '6038',
#  '10719',
#  '11407',
#  '3140',
#  '228',
#  '1964',
#  '9486',
#  '8940',
#  '10094',
#  '3815',
#  '6979',
#  '9492',
#  '8954',
#  '1780',
#  '1958',
#  '3197',
#  '10916',
#  '2289',
#  '5280',
#  '3829',
#  '6951',
#  '7497',
#  '6789',
#  '7483',
#  '566',
#  '8968',
#  '5294',
#  '10902',
#  '4834',
#  '1794',
#  '200',
#  '9647',
#  '6574',
#  '2712',
#  '4405',
#  '2074',
#  '9121',
#  '6206',
#  '1569',
#  '7118',
#  '4411',
#  '11639',
#  '10527',
#  '2060',
#  '5069',
#  '10241',
#  '2706',
#  '3418',
#  '943',
#  '9653',
#  '5041',
#  '3430',
#  '11177',
#  '7656',
#  '8565',
#  '1227',
#  '6548',
#  '8203',
#  '4439',
#  '3356',
#  '11611',
#  '2048',
#  '3342',
#  '9109',
#  '7124',
#  '7642',
#  '8571',
#  '1233',
#  '5055',
#  '3424',
#  '11163',
#  '11188',
#  '2909',
#  '10296',
#  '7871',
#  '994',
#  '11836',
#  '5900',
#  '11822',
#  '5914',
#  '7865',
#  '9690',
#  '10282',
#  '770',
#  '7695',
#  '9860',
#  '5082',
#  '3395',
#  '1596',
#  '3381',
#  '5928',
#  '5096',
#  '764',
#  '7681',
#  '3380',
#  '1597',
#  '9875',
#  '7680',
#  '7858',
#  '5097',
#  '4389',
#  '2920',
#  '5083',
#  '2934',
#  '7694',
#  '771',
#  '1583',
#  '11823',
#  '10283',
#  '9849',
#  '9691',
#  '7864',
#  '759',
#  '995',
#  '9685',
#  '7870',
#  '2908',
#  '11189',
#  '5901',
#  '11837',
#  '8216',
#  '7125',
#  '1554',
#  '9108',
#  '11604',
#  '3343',
#  '5054',
#  '1232',
#  '8570',
#  '7643',
#  '6549',
#  '8564',
#  '11176',
#  '10268',
#  '5040',
#  '5726',
#  '11610',
#  '3357',
#  '7131',
#  '1540',
#  '2061',
#  '10526',
#  '11638',
#  '4410',
#  '7119',
#  '6207',
#  '6561',
#  '9652',
#  '942',
#  '4376',
#  '3419',
#  '10240',
#  '5068',
#  '4362',
#  '2713',
#  '9646',
#  '956',
#  '6213',
#  '9120',
#  '4404',
#  '5295',
#  '8969',
#  '7482',
#  '6944',
#  '201',
#  '1795',
#  '4835',
#  '10903',
#  '4821',
#  '1959',
#  '1781',
#  '215',
#  '573',
#  '6788',
#  '7496',
#  '6950',
#  '8955',
#  '9493',
#  '6978',
#  '10081',
#  '1971',
#  '1965',
#  '10095',
#  '9487',
#  '8799',
#  '7441',
#  '8772',
#  '6987',
#  '5256',
#  '11360',
#  '11406',
#  '10718',
#  '6039',
#  '1756',
#  '8000',
#  '3155',
#  '11412',
#  '5242',
#  '3633',
#  '11374',
#  '7455',
#  '8766',
#  '6993',
#  '1024',
#  '9478',
#  '10042',
#  '2505',
#  '4174',
#  '9450',
#  '9336',
#  '6005',
#  '4612',
#  '10724',
#  '4606',
#  '3169',
#  '10730',
#  '2277',
#  '5518',
#  '9322',
#  '8982',
#  '6777',
#  '10056',
#  '2511',
#  '3948',
#  '3790',
#  '6830',
#  '413',
#  '1187',
#  '1839',
#  '10877',
#  '5487',
#  '4941',
#  '10863',
#  '7284',
#  '6824',
#  '1193',
#  '407',
#  '3784',
#  '8821',
#  '3974',
#  '10693',
#  '349',
#  '9281',
#  '1805',
#  '1811',
#  '11599',
#  '4969',
#  '3960',
#  '9518',
#  '7535',
#  '8606',
#  '3753',
#  '11214',
#  '4982',
#  '3035',
#  '11572',
#  '7253',
#  '8160',
#  '1622',
#  '8174',
#  '6159',
#  '5450',
#  '4996',
#  '10678',
#  '3021',
#  '4028',
#  '3747',
#  '11200',
#  '7521',
#  '8612',
#  '11228',
#  '10136',
#  '2471',
#  '6617',
#  '1178',
#  '7509',
#  '6171',
#  '5478',
#  '2317',
#  '3009',
#  '10644',
#  '8148',
#  '9256',
#  '9530',
#  '6603',
#  '4014',
#  '10122',
#  '2465',
#  '5685',
#  '7092',
#  '177',
#  '1385',
#  '611',
#  '89',
#  '2854',
#  '3586',
#  '2840',
#  '2698',
#  '605',
#  '1391',
#  '7938',
#  '9915',
#  '163',
#  '5691',
#  '5849',
#  '9083',
#  '10491',
#  '7910',
#  '7904',
#  '10485',
#  '11943',
#  '5875',
#  '8389',
#  '9097',
#  '11770',
#  '3237',
#  '2129',
#  '3551',
#  '8404',
#  '1346',
#  '6429',
#  '8410',
#  '7723',
#  '1352',
#  '5134',
#  '11002',
#  '3545',
#  '2883',
#  '3223',
#  '5652',
#  '8376',
#  '7045',
#  '4564',
#  '10452',
#  '11994',
#  '188',
#  '8438',
#  '836',
#  '6415',
#  '76',
#  '10334',
#  '4202',
#  '5108',
#  '4216',
#  '822',
#  '6401',
#  '9732',
#  '9054',
#  '1408',
#  '7079',
#  '4570',
#  '11758',
#  '2101',
#  '10446',
#  '11980',
#  '4200',
#  '2671',
#  '10336',
#  '74',
#  '9724',
#  '1378',
#  '7709',
#  '834',
#  '6371',
#  '9042',
#  '5678',
#  '11996',
#  '2117',
#  '10450',
#  '11982',
#  '2103',
#  '4572',
#  '6365',
#  '9056',
#  '60',
#  '820',
#  '10322',
#  '48',
#  '1344',
#  '808',
#  '7735',
#  '2895',
#  '11014',
#  '3553',
#  '11772',
#  '8360',
#  '1422',
#  '7047',
#  '6359',
#  '10478',
#  '5888',
#  '4228',
#  '2881',
#  '11000',
#  '5136',
#  '1350',
#  '8412',
#  '7721',
#  '7912',
#  '5863',
#  '11955',
#  '10493',
#  '149',
#  '5877',
#  '10487',
#  '7906',
#  '2856',
#  '9903',
#  '613',
#  '161',
#  '7084',
#  '9917',
#  '1393',
#  '2842',
#  '3584',
#  '4764',
#  '10652',
#  '2315',
#  '9240',
#  '388',
#  '8638',
#  '6615',
#  '10134',
#  '2473',
#  '4002',
#  '5308',
#  '10120',
#  '2467',
#  '3779',
#  '4016',
#  '9532',
#  '6601',
#  '9254',
#  '6167',
#  '1608',
#  '7279',
#  '4770',
#  '11558',
#  '2301',
#  '1620',
#  '7251',
#  '8162',
#  '4758',
#  '3037',
#  '11570',
#  '2329',
#  '4980',
#  '5446',
#  '5320',
#  '10108',
#  '3751',
#  '11216',
#  '8604',
#  '6629',
#  '7523',
#  '8610',
#  '1152',
#  '5334',
#  '3745',
#  '11202',
#  '3023',
#  '4994',
#  '5452',
#  '1634',
#  '7245',
#  '8176',
#  '9283',
#  '10691',
#  '3976',
#  '8823',
#  '8837',
#  '439',
#  '10685',
#  '8189',
#  '9297',
#  '4943',
#  '5485',
#  '10875',
#  '7292',
#  '377',
#  '1185',
#  '6832',
#  '3792',
#  '3786',
#  '2498',
#  '1191',
#  '6826',
#  '7286',
#  '6198',
#  '5491',
#  '10861',
#  '2261',
#  '11438',
#  '4610',
#  '7319',
#  '1768',
#  '9334',
#  '6007',
#  '6761',
#  '3619',
#  '4162',
#  '10054',
#  '9446',
#  '8758',
#  '6013',
#  '10732',
#  '2275',
#  '7325',
#  '1754',
#  '9308',
#  '5532',
#  '3625',
#  '11362',
#  '1032',
#  '8770',
#  '6749',
#  '7457',
#  '8764',
#  '3631',
#  '11376',
#  '5526',
#  '2249',
#  '11410',
#  '4638',
#  '1740',
#  '10083',
#  '9491',
#  '8957',
#  '8943',
#  '10097',
#  '3816',
#  '11389',
#  '10929',
#  '1967',
#  '3180',
#  '10901',
#  '1797',
#  '203',
#  '6946',
#  '7480',
#  '5297',
#  '4189',
#  '5283',
#  '7494',
#  '571',
#  '3194',
#  '10242',
#  '940',
#  '9888',
#  '798',
#  '6563',
#  '9650',
#  '6205',
#  '8228',
#  '4412',
#  '2063',
#  '2077',
#  '10530',
#  '6211',
#  '9122',
#  '954',
#  '1218',
#  '6577',
#  '10256',
#  '11148',
#  '4360',
#  '8572',
#  '7641',
#  '1230',
#  '7899',
#  '5056',
#  '2739',
#  '11160',
#  '3427',
#  '4348',
#  '3341',
#  '10518',
#  '5730',
#  '7127',
#  '1542',
#  '8200',
#  '7133',
#  '11612',
#  '3355',
#  '5042',
#  '11174',
#  '3433',
#  '968',
#  '8566',
#  '7655',
#  '7866',
#  '9693',
#  '10281',
#  '11821',
#  '11835',
#  '5903',
#  '7872',
#  '8599',
#  '2922',
#  '5095',
#  '767',
#  '7682',
#  '9877',
#  '3382',
#  '11809',
#  '3396',
#  '1581',
#  '773',
#  '6588',
#  '9863',
#  '5081',
#  '1580',
#  '2089',
#  '5080',
#  '9862',
#  '6589',
#  '772',
#  '9876',
#  '7683',
#  '766',
#  '5094',
#  '1594',
#  '8598',
#  '9686',
#  '7873',
#  '10294',
#  '10280',
#  '982',
#  '7867',
#  '11820',
#  '3354',
#  '8201',
#  '9679',
#  '1225',
#  '7654',
#  '969',
#  '11175',
#  '5043',
#  '4349',
#  '3426',
#  '2738',
#  '7898',
#  '1231',
#  '1557',
#  '6238',
#  '5731',
#  '10519',
#  '11607',
#  '9123',
#  '5719',
#  '2076',
#  '3368',
#  '4407',
#  '4361',
#  '11149',
#  '10257',
#  '9645',
#  '6576',
#  '1219',
#  '7668',
#  '9651',
#  '6562',
#  '799',
#  '9889',
#  '941',
#  '10243',
#  '2704',
#  '10525',
#  '2062',
#  '4413',
#  '7495',
#  '6953',
#  '5282',
#  '4822',
#  '10914',
#  '3195',
#  '216',
#  '202',
#  '1796',
#  '4188',
#  '5296',
#  '564',
#  '7481',
#  '11388',
#  '3817',
#  '8942',
#  '9484',
#  '10928',
#  '8956',
#  '558',
#  '9490',
#  '5241',
#  '11377',
#  '3630',
#  '8765',
#  '6990',
#  '1027',
#  '6748',
#  '1999',
#  '7330',
#  '4639',
#  '3156',
#  '2248',
#  '5527',
#  '11405',
#  '3142',
#  '5533',
#  '9309',
#  '1755',
#  '8017',
#  '7324',
#  '8771',
#  '7442',
#  '11363',
#  '3624',
#  '8759',
#  '9447',
#  '4163',
#  '10733',
#  '6012',
#  '9321',
#  '6006',
#  '9335',
#  '1769',
#  '2260',
#  '10727',
#  '5269',
#  '2506',
#  '10041',
#  '3618',
#  '8995',
#  '6760',
#  '9453',
#  '1190',
#  '404',
#  '10860',
#  '5490',
#  '4956',
#  '362',
#  '6199',
#  '7287',
#  '376',
#  '7293',
#  '10874',
#  '4942',
#  '3793',
#  '6833',
#  '410',
#  '1184',
#  '3963',
#  '9296',
#  '8188',
#  '1812',
#  '10684',
#  '10848',
#  '10690',
#  '9282',
#  '1806',
#  '8822',
#  '11203',
#  '3744',
#  '5335',
#  '8611',
#  '7522',
#  '8177',
#  '7244',
#  '1635',
#  '5453',
#  '4995',
#  '11565',
#  '3022',
#  '5447',
#  '2328',
#  '11571',
#  '3036',
#  '8163',
#  '7250',
#  '1621',
#  '6628',
#  '1147',
#  '7536',
#  '10109',
#  '3988',
#  '6600',
#  '9533',
#  '3778',
#  '10121',
#  '2300',
#  '10647',
#  '4771',
#  '7278',
#  '6166',
#  '389',
#  '9241',
#  '2314',
#  '10653',
#  '4765',
#  '4003',
#  '2472',
#  '10135',
#  '6614',
#  '9527',
#  '8639',
#  '7085',
#  '5692',
#  '3585',
#  '2843',
#  '606',
#  '1392',
#  '9916',
#  '1386',
#  '612',
#  '3591',
#  '2857',
#  '5686',
#  '4598',
#  '7091',
#  '174',
#  '10486',
#  '11940',
#  '5876',
#  '11798',
#  '9094',
#  '7907',
#  '7913',
#  '9080',
#  '148',
#  '11954',
#  ...]

# %%
train_pca = pd.DataFrame(train_pca, columns=['pca1', 'pca2'])
train_pca['index'] = id_train
train_pca.head()
# Out:
#        pca1      pca2  index
# 0 -3.900484 -0.599684   4217
# 1 -3.037692 -1.516021   3578
# 2 -3.892711  1.487832  10321
# 3  0.077549 -0.060659   2666
# 4  2.466613  1.366047  11981

# %%
df_train.head()
# Out:
#    index  rooms  retail_price    sqft
# 0   5832    2.0        299000  1295.0
# 1   5584    3.0        299000  1566.0
# 2   9408    5.0        499990  3068.0
# 3   4644    4.0        849900  2230.0
# 4   5739    3.0        333490  1898.0

# %%
train_pca['index'] = train_pca['index'].astype(int)
df_train['index'] = df_train['index'].astype(int)
df_train = df_train.merge(train_pca, on='index', how='left')

# %%
test_pca['index'] = test_pca['index'].astype(int)
df_test['index'] = df_test['index'].astype(int)
df_test = df_test.merge(test_pca, on='index', how='left')

# %%
train_pca
# Out:
#           pca1      pca2  index
# 0    -3.900484 -0.599684   4217
# 1    -3.037692 -1.516021   3578
# 2    -3.892711  1.487832  10321
# 3     0.077549 -0.060659   2666
# 4     2.466613  1.366047  11981
# ...        ...       ...    ...
# 8395 -4.991081 -1.999732   3561
# 8396 -1.545679 -5.180035   8434
# 8397  1.231549 -1.450335   7707
# 8398 -2.609299 -3.226620   6419
# 8399 -2.309372 -1.178271   1376
#
# [8400 rows x 3 columns]

# %%
df_train.head()
# Out:
#    index  rooms  retail_price    sqft    pca1_x    pca2_x
# 0   5832    2.0        299000  1295.0 -2.587846 -3.748382
# 1   5584    3.0        299000  1566.0 -2.129145 -3.325030
# 2   9408    5.0        499990  3068.0  1.026178 -3.387645
# 3   4644    4.0        849900  2230.0 -4.221012  0.773358
# 4   5739    3.0        333490  1898.0 -2.644358 -3.467030

# %%
df_test.head()
# Out:
#    index  rooms  sqft      pca1      pca2
# 0   3076      3  1510 -0.835852  0.162267
# 1   3218      4  2342  1.024523  3.522499
# 2   9213      2  2845 -2.465148 -1.889967
# 3  10018      4  2379  2.952842 -4.657385
# 4  11355      4  1836  0.023438  0.986804

# %%
df_train.rename(columns = {'pca1_x':'pca1', 'pca2_x':'pca2'}, inplace = True)

# %%
df_train.head()
# Out:
#    index  rooms  retail_price    sqft      pca1      pca2
# 0   5832    2.0        299000  1295.0 -2.587846 -3.748382
# 1   5584    3.0        299000  1566.0 -2.129145 -3.325030
# 2   9408    5.0        499990  3068.0  1.026178 -3.387645
# 3   4644    4.0        849900  2230.0 -4.221012  0.773358
# 4   5739    3.0        333490  1898.0 -2.644358 -3.467030

# %%
df_test.head()
# Out:
#    index  rooms  sqft      pca1      pca2
# 0   3076      3  1510 -0.835852  0.162267
# 1   3218      4  2342  1.024523  3.522499
# 2   9213      2  2845 -2.465148 -1.889967
# 3  10018      4  2379  2.952842 -4.657385
# 4  11355      4  1836  0.023438  0.986804

# %%
train_data = pd.read_csv('train_pca.csv', index_col=0)
test_data = pd.read_csv('test_pca.csv', index_col=0)
train_data.dropna(inplace=True)
x_train, y_train = train_data.drop('retail_price', axis=1), train_data['retail_price']
x_test, y_test = test_data, train_data['retail_price']

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8061 entries, 0 to 8399
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   8061 non-null   int64
#  1   rooms   8061 non-null   float64
#  2   sqft    8061 non-null   float64
#  3   pca1    8061 non-null   float64
#  4   pca2    8061 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 377.9 KB

# %%
def scale_datasets(x_train, x_test):
    standard_scaler = StandardScaler()
    x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns)
    x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns)
    return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
hidden_units1 = 160
hidden_units2 = 480
hidden_units3 = 256
learning_rate = 0.01
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
model = build_model_using_sequential()

# %%
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/10
#   1/101 [..............................] - ETA: 45s - loss: 178.9184 - mean_squared_logarithmic_error: 178.9184
# 2023-01-23 00:14:22.816527: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 101/101 [==============================] - 2s 13ms/step - loss: 17.6664 - mean_squared_logarithmic_error: 17.6292 - val_loss: 2.1834 - val_mean_squared_logarithmic_error: 2.1953
# Epoch 2/10
#   1/101 [..............................] - ETA: 0s - loss: 2.2078 - mean_squared_logarithmic_error: 2.2078
# 2023-01-23 00:14:24.147757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 101/101 [==============================] - 1s 10ms/step - loss: 1.0689 - mean_squared_logarithmic_error: 1.0676 - val_loss: 0.4674 - val_mean_squared_logarithmic_error: 0.4690
# Epoch 3/10
# 101/101 [==============================] - 1s 9ms/step - loss: 0.3509 - mean_squared_logarithmic_error: 0.3506 - val_loss: 0.2707 - val_mean_squared_logarithmic_error: 0.2693
# Epoch 4/10
# 101/101 [==============================] - 1s 9ms/step - loss: 0.2640 - mean_squared_logarithmic_error: 0.2640 - val_loss: 0.2408 - val_mean_squared_logarithmic_error: 0.2386
# Epoch 5/10
# 101/101 [==============================] - 1s 9ms/step - loss: 0.2427 - mean_squared_logarithmic_error: 0.2429 - val_loss: 0.2289 - val_mean_squared_logarithmic_error: 0.2265
# Epoch 6/10
# 101/101 [==============================] - 1s 9ms/step - loss: 0.2330 - mean_squared_logarithmic_error: 0.2329 - val_loss: 0.2210 - val_mean_squared_logarithmic_error: 0.2187
# Epoch 7/10
# 101/101 [==============================] - 1s 9ms/step - loss: 0.2261 - mean_squared_logarithmic_error: 0.2261 - val_loss: 0.2140 - val_mean_squared_logarithmic_error: 0.2118
# Epoch 8/10
# 101/101 [==============================] - 1s 11ms/step - loss: 0.2188 - mean_squared_logarithmic_error: 0.2187 - val_loss: 0.2079 - val_mean_squared_logarithmic_error: 0.2059
# Epoch 9/10
# 101/101 [==============================] - 1s 10ms/step - loss: 0.2128 - mean_squared_logarithmic_error: 0.2128 - val_loss: 0.2024 - val_mean_squared_logarithmic_error: 0.2005
# Epoch 10/10
# 101/101 [==============================] - 1s 10ms/step - loss: 0.2076 - mean_squared_logarithmic_error: 0.2076 - val_loss: 0.1976 - val_mean_squared_logarithmic_error: 0.1959

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mean_squared_logarithmic_error')

# %%
x_test_scaled.head()
# Out:
#       index     rooms      sqft      pca1      pca2
# 0 -0.848891 -0.473747 -0.620265 -0.098302  0.025200
# 1 -0.807980  0.498719  0.172016  0.113559  0.578550
# 2  0.919211 -1.446214  0.651003 -0.283847 -0.312753
# 3  1.151135  0.498719  0.207250  0.333158 -0.768481
# 4  1.536332  0.498719 -0.309828 -0.000445  0.160982

# %%
x_test['retail_price'] = model.predict(x_test_scaled.values)
# Out:
#  59/113 [==============>...............] - ETA: 0s
# 2023-01-23 00:16:18.904431: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 113/113 [==============================] - 0s 3ms/step

# %%
x_test.head()
# Out:
#    index  rooms  sqft      pca1      pca2  retail_price
# 0   3076      3  1510 -0.835852  0.162267  437334.00000
# 1   3218      4  2342  1.024523  3.522499  567471.12500
# 2   9213      2  2845 -2.465148 -1.889967  642018.68750
# 3  10018      4  2379  2.952842 -4.657385  562039.68750
# 4  11355      4  1836  0.023438  0.986804  482866.90625

# %%
x_test.drop(['rooms','sqft', 'pca1', 'pca2'], axis=1, inplace=True)
x_test.head()
# Out:
#    index  retail_price
# 0   3076  437334.00000
# 1   3218  567471.12500
# 2   9213  642018.68750
# 3  10018  562039.68750
# 4  11355  482866.90625

# %%
x_test.to_csv('submission_trial_1.csv', index=False)
